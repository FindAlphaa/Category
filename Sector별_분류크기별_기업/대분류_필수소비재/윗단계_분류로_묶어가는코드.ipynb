# %% [markdown]
# # description과 리프노드분류로 분류한 정보가 있는 파일

# %%
import pandas as pd
data = pd.read_csv("필수소비재_개요_리프.csv", encoding='cp949')

new_classification_dict = {}

for _, row in data.iterrows():
    # 'sub_classfication' 값이 문자열인지 확인
    if isinstance(row['sub_classfication'], str):
        # 각 sub_classfication 값을 쉼표로 분리
        for category in row['sub_classfication'].split(', '):
            companies = new_classification_dict.get(category, [])
            if row['Company'] not in companies:
                companies.append(row['Company'])
            new_classification_dict[category] = companies

new_classification_dict
# Out:
# {'식품 도매': ['MH에탄올',
#   '모나리자',
#   '선진',
#   '오뚜기',
#   '오리온',
#   '카나리아바이오',
#   '푸드웰',
#   '한국맥널티',
#   'CJ씨푸드',
#   'CJ제일제당',
#   '농심',
#   '동원F&B',
#   '보락',
#   '빙그레',
#   '사조대림',
#   '신송홀딩스',
#   '조흥',
#   '보라티알',
#   '커머스마이너',
#   '케이씨피드',
#   '하림',
#   '흥국에프엔비',
#   '동서',
#   '동원수산',
#   '롯데웰푸드',
#   '사조씨푸드',
#   '샘표식품',
#   '팜스코',
#   '해태제과식품',
#   '에스앤디',
#   '인산가',
#   '교촌에프앤비',
#   '사조산업',
#   '삼양식품',
#   '대주산업',
#   '우양',
#   '한일사료',
#   '남양유업',
#   '대상',
#   '대한제당',
#   '샘표',
#   '크라운제과',
#   '크라운해태홀딩스',
#   'CJ프레시웨이',
#   'DSEN',
#   '팜스토리',
#   'SPC삼립',
#   '사조오양',
#   '삼양사',
#   '신라에스지',
#   '엠에스씨',
#   '이지바이오',
#   '진로발효',
#   '농심홀딩스',
#   '풀무원',
#   '하림지주',
#   '한국가구',
#   '보해양조',
#   '한성기업',
#   '현대코퍼레이션홀딩스',
#   '마니커에프앤지',
#   '미래생명자원',
#   '에이치피오',
#   '오에스피',
#   '이지홀딩스',
#   '정다운'],
#  '식품 소매': ['MH에탄올',
#   '선진',
#   '오뚜기',
#   '오리온',
#   '카나리아바이오',
#   '푸드웰',
#   '한국맥널티',
#   'CJ씨푸드',
#   'CJ제일제당',
#   '농심',
#   '동원F&B',
#   '보락',
#   '사조대림',
#   '신송홀딩스',
#   '조흥',
#   '보라티알',
#   '커머스마이너',
#   '케이씨피드',
#   '하림',
#   '흥국에프엔비',
#   '동서',
#   '동원수산',
#   '롯데웰푸드',
#   '사조씨푸드',
#   '샘표식품',
#   '팜스코',
#   '해태제과식품',
#   '에스앤디',
#   '인산가',
#   '교촌에프앤비',
#   '사조산업',
#   '삼양식품',
#   '대주산업',
#   '스피어파워',
#   '우양',
#   '한일사료',
#   '대상',
#   '대한제당',
#   '샘표',
#   '크라운제과',
#   '크라운해태홀딩스',
#   '케이엠제약',
#   '큐로홀딩스',
#   '팜스토리',
#   'SPC삼립',
#   '사조오양',
#   '삼양사',
#   '신라에스지',
#   '엠에스씨',
#   '이지바이오',
#   '진로발효',
#   '농심홀딩스',
#   '풀무원',
#   '하림지주',
#   '한국가구',
#   '한성기업',
#   '마니커에프앤지',
#   '미래생명자원',
#   '에이치피오',
#   '오에스피',
#   '이지홀딩스'],
#  '청량 음료': ['MH에탄올',
#   '푸드웰',
#   '농심',
#   '동원F&B',
#   '무학',
#   '하이트진로',
#   '매일홀딩스',
#   '흥국에프엔비',
#   '매일유업',
#   '삼양식품',
#   '우양',
#   '풍국주정',
#   '남양유업',
#   'SPC삼립',
#   '진로발효',
#   '농심홀딩스',
#   '대한제분',
#   '풀무원',
#   '창해에탄올',
#   '보해양조',
#   '제주맥주'],
#  '포장 식품': ['MH에탄올',
#   '선진',
#   '오뚜기',
#   '오리온',
#   '카나리아바이오',
#   '푸드웰',
#   '한국맥널티',
#   'CJ씨푸드',
#   'CJ제일제당',
#   '농심',
#   '동원F&B',
#   '보락',
#   '빙그레',
#   '사조대림',
#   '신송홀딩스',
#   '조흥',
#   '보라티알',
#   '커머스마이너',
#   '케이씨피드',
#   '하림',
#   '흥국에프엔비',
#   '동서',
#   '동원산업',
#   '동원수산',
#   '롯데웰푸드',
#   '사조씨푸드',
#   '샘표식품',
#   '우성',
#   '팜스코',
#   '해태제과식품',
#   '매일유업',
#   '에스앤디',
#   '인산가',
#   '교촌에프앤비',
#   '사조산업',
#   '삼양식품',
#   '대주산업',
#   '우양',
#   '한일사료',
#   '대상',
#   '대한제당',
#   '샘표',
#   '크라운제과',
#   '크라운해태홀딩스',
#   '팜스토리',
#   'SPC삼립',
#   '사조오양',
#   '삼양사',
#   '신라에스지',
#   '엠에스씨',
#   '이지바이오',
#   '진로발효',
#   '고려산업',
#   '농심홀딩스',
#   '사조동아원',
#   '풀무원',
#   '하림지주',
#   '한성기업',
#   '현대코퍼레이션홀딩스',
#   '마니커에프앤지',
#   '미래생명자원',
#   '에이치피오',
#   '오에스피',
#   '이지홀딩스',
#   '정다운'],
#  '증류업체와 양조업체': ['MH에탄올', '무학', '하이트진로', '풍국주정', '하이트진로홀딩스', '창해에탄올', '보해양조'],
#  '가정용품': ['모나리자', 'TS트릴리온', '전진바이오팜', '삼정펄프', '태양'],
#  '약품 소매': ['오리온',
#   '푸드웰',
#   '한국맥널티',
#   'CJ제일제당',
#   '보락',
#   '하림',
#   '스피어파워',
#   '대한제당',
#   '케이엠제약',
#   '큐로홀딩스',
#   '신라에스지',
#   '엠에스씨',
#   '이지바이오',
#   '한국가구'],
#  '담배': ['보락',
#   '보라티알',
#   '동서',
#   '교촌에프앤비',
#   'CJ프레시웨이',
#   'DSEN',
#   '큐로홀딩스',
#   '신라에스지',
#   '현대코퍼레이션홀딩스'],
#  '맥주 양조업자': ['하이트진로', '교촌에프앤비', '하이트진로홀딩스', '제주맥주'],
#  '개인용품': ['TS트릴리온', '메지온', '비비씨'],
#  '고기': ['마니커',
#   '사조씨푸드',
#   '교촌에프앤비',
#   '사조산업',
#   '삼양식품',
#   '신라교역',
#   'DSEN',
#   '동우팜투테이블',
#   '체리부로',
#   '마니커에프앤지'],
#  '농산물': ['신라교역']}

# %% [markdown]
# # 리프노드_기업들로 csv 파일 저장코드

# %%
# 딕셔너리를 데이터프레임으로 변환
classification_df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in new_classification_dict.items()]))

# 데이터프레임을 CSV 파일로 저장
classification_csv_path = '필수소비재_리프노드_기업들.csv'
classification_df.to_csv(classification_csv_path, encoding='cp949', index=False)

classification_csv_path
# Out:
# '필수소비재_리프노드_기업들.csv'

# %% [markdown]
# # 리프노드 -> 소분류

# %%
# 소소분류 기업들
import pandas as pd

# CSV 파일을 읽는다
df = pd.read_csv("필수소비재_리프노드_기업들.csv", encoding='cp949')

# DataFrame을 딕셔너리로 변환한다
result_dict = {}
for column in df.columns:
    # NaN 값은 무시한다
    result_dict[column] = df[column].dropna().tolist()

print(result_dict)
# Out:
# {'식품 도매': ['MH에탄올', '모나리자', '선진', '오뚜기', '오리온', '카나리아바이오', '푸드웰', '한국맥널티', 'CJ씨푸드', 'CJ제일제당', '농심', '동원F&B', '보락', '빙그레', '사조대림', '신송홀딩스', '조흥', '보라티알', '커머스마이너', '케이씨피드', '하림', '흥국에프엔비', '동서', '동원수산', '롯데웰푸드', '사조씨푸드', '샘표식품', '팜스코', '해태제과식품', '에스앤디', '인산가', '교촌에프앤비', '사조산업', '삼양식품', '대주산업', '우양', '한일사료', '남양유업', '대상', '대한제당', '샘표', '크라운제과', '크라운해태홀딩스', 'CJ프레시웨이', 'DSEN', '팜스토리', 'SPC삼립', '사조오양', '삼양사', '신라에스지', '엠에스씨', '이지바이오', '진로발효', '농심홀딩스', '풀무원', '하림지주', '한국가구', '보해양조', '한성기업', '현대코퍼레이션홀딩스', '마니커에프앤지', '미래생명자원', '에이치피오', '오에스피', '이지홀딩스', '정다운'], '식품 소매': ['MH에탄올', '선진', '오뚜기', '오리온', '카나리아바이오', '푸드웰', '한국맥널티', 'CJ씨푸드', 'CJ제일제당', '농심', '동원F&B', '보락', '사조대림', '신송홀딩스', '조흥', '보라티알', '커머스마이너', '케이씨피드', '하림', '흥국에프엔비', '동서', '동원수산', '롯데웰푸드', '사조씨푸드', '샘표식품', '팜스코', '해태제과식품', '에스앤디', '인산가', '교촌에프앤비', '사조산업', '삼양식품', '대주산업', '스피어파워', '우양', '한일사료', '대상', '대한제당', '샘표', '크라운제과', '크라운해태홀딩스', '케이엠제약', '큐로홀딩스', '팜스토리', 'SPC삼립', '사조오양', '삼양사', '신라에스지', '엠에스씨', '이지바이오', '진로발효', '농심홀딩스', '풀무원', '하림지주', '한국가구', '한성기업', '마니커에프앤지', '미래생명자원', '에이치피오', '오에스피', '이지홀딩스'], '청량 음료': ['MH에탄올', '푸드웰', '농심', '동원F&B', '무학', '하이트진로', '매일홀딩스', '흥국에프엔비', '매일유업', '삼양식품', '우양', '풍국주정', '남양유업', 'SPC삼립', '진로발효', '농심홀딩스', '대한제분', '풀무원', '창해에탄올', '보해양조', '제주맥주'], '포장 식품': ['MH에탄올', '선진', '오뚜기', '오리온', '카나리아바이오', '푸드웰', '한국맥널티', 'CJ씨푸드', 'CJ제일제당', '농심', '동원F&B', '보락', '빙그레', '사조대림', '신송홀딩스', '조흥', '보라티알', '커머스마이너', '케이씨피드', '하림', '흥국에프엔비', '동서', '동원산업', '동원수산', '롯데웰푸드', '사조씨푸드', '샘표식품', '우성', '팜스코', '해태제과식품', '매일유업', '에스앤디', '인산가', '교촌에프앤비', '사조산업', '삼양식품', '대주산업', '우양', '한일사료', '대상', '대한제당', '샘표', '크라운제과', '크라운해태홀딩스', '팜스토리', 'SPC삼립', '사조오양', '삼양사', '신라에스지', '엠에스씨', '이지바이오', '진로발효', '고려산업', '농심홀딩스', '사조동아원', '풀무원', '하림지주', '한성기업', '현대코퍼레이션홀딩스', '마니커에프앤지', '미래생명자원', '에이치피오', '오에스피', '이지홀딩스', '정다운'], '증류업체와 양조업체': ['MH에탄올', '무학', '하이트진로', '풍국주정', '하이트진로홀딩스', '창해에탄올', '보해양조'], '가정용품': ['모나리자', 'TS트릴리온', '전진바이오팜', '삼정펄프', '태양'], '약품 소매': ['오리온', '푸드웰', '한국맥널티', 'CJ제일제당', '보락', '하림', '스피어파워', '대한제당', '케이엠제약', '큐로홀딩스', '신라에스지', '엠에스씨', '이지바이오', '한국가구'], '담배': ['보락', '보라티알', '동서', '교촌에프앤비', 'CJ프레시웨이', 'DSEN', '큐로홀딩스', '신라에스지', '현대코퍼레이션홀딩스'], '맥주 양조업자': ['하이트진로', '교촌에프앤비', '하이트진로홀딩스', '제주맥주'], '개인용품': ['TS트릴리온', '메지온', '비비씨'], '고기': ['마니커', '사조씨푸드', '교촌에프앤비', '사조산업', '삼양식품', '신라교역', 'DSEN', '동우팜투테이블', '체리부로', '마니커에프앤지'], '농산물': ['신라교역']}

# %%
classification = {
    '약품 소매': ['약품 소매'],
    '식품 도매': ['식품 도매'],
    '식품 소매': ['식품 소매'],
    '하이퍼마켓과 대형 쇼핑센터': ['하이퍼마켓과 대형 쇼핑센터'],
    '음료': ['맥주 양조업자', '증류업체와 양조업체', '청량 음료'],
    '식품': ['농산물', '포장 식품', '고기'],
    '가정용품': ['가정용품'],
    '개인용품' : ['개인용품', '담배']
}

# %%
# 소소분류 -> 소분류
new_classification_companies = {}

for new_category, old_categories in classification.items():
    new_classification_companies[new_category] = []
    
    for old_category in old_categories:
        if old_category in result_dict:
            new_classification_companies[new_category].extend(result_dict[old_category])
            
    # 중복된 기업명 제거
    new_classification_companies[new_category] = list(set(new_classification_companies[new_category]))

# 새로운 분류로 DataFrame을 생성하고 CSV로 저장한다
df_new_classified = pd.DataFrame.from_dict(new_classification_companies, orient='index').transpose()
df_new_classified.to_csv('필수소비재_소분류_기업들.csv', index=False, encoding='cp949')

# %% [markdown]
# # 소분류 -> 중분류

# %%
# CSV 파일을 읽는다
df = pd.read_csv("필수소비재_소분류_기업들.csv", encoding='cp949')

# DataFrame을 딕셔너리로 변환한다
small_dict = {}
for column in df.columns:
    # NaN 값은 무시한다
    small_dict[column] = df[column].dropna().tolist()

print(small_dict)
# Out:
# {'약품 소매': ['엠에스씨', '한국맥널티', '큐로홀딩스', '스피어파워', '대한제당', '하림', '케이엠제약', '이지바이오', '보락', 'CJ제일제당', '오리온', '한국가구', '푸드웰', '신라에스지'], '식품 도매': ['한성기업', '오뚜기', '미래생명자원', '정다운', '마니커에프앤지', '교촌에프앤비', 'CJ제일제당', '오리온', '사조오양', '한국가구', '삼양식품', '푸드웰', '대상', '카나리아바이오', 'MH에탄올', 'CJ프레시웨이', '보라티알', '롯데웰푸드', '조흥', '팜스코', '에스앤디', '풀무원', '인산가', '하림지주', '이지바이오', '동원F&B', '하림', '남양유업', '오에스피', '동원수산', '이지홀딩스', '케이씨피드', '사조산업', '동서', '농심', '신라에스지', '선진', '해태제과식품', '엠에스씨', '삼양사', '팜스토리', '진로발효', '빙그레', 'SPC삼립', '대한제당', '농심홀딩스', '모나리자', '샘표', '크라운해태홀딩스', '현대코퍼레이션홀딩스', 'DSEN', '샘표식품', '보해양조', '우양', '신송홀딩스', '한국맥널티', '크라운제과', '에이치피오', '대주산업', 'CJ씨푸드', '한일사료', '보락', '커머스마이너', '흥국에프엔비', '사조씨푸드', '사조대림'], '식품 소매': ['한성기업', '큐로홀딩스', '오뚜기', '미래생명자원', '마니커에프앤지', '교촌에프앤비', 'CJ제일제당', '오리온', '사조오양', '한국가구', '삼양식품', '푸드웰', '대상', '카나리아바이오', 'MH에탄올', '보라티알', '롯데웰푸드', '조흥', '팜스코', '에스앤디', '풀무원', '인산가', '하림지주', '이지바이오', '동원F&B', '하림', '오에스피', '동원수산', '이지홀딩스', '케이씨피드', '사조산업', '동서', '농심', '신라에스지', '선진', '해태제과식품', '엠에스씨', '삼양사', '팜스토리', '진로발효', 'SPC삼립', '대한제당', '농심홀딩스', '샘표', '크라운해태홀딩스', '케이엠제약', '샘표식품', '우양', '신송홀딩스', '한국맥널티', '크라운제과', '에이치피오', '대주산업', '스피어파워', 'CJ씨푸드', '한일사료', '보락', '커머스마이너', '흥국에프엔비', '사조씨푸드', '사조대림'], '하이퍼마켓과 대형 쇼핑센터': [], '음료': ['제주맥주', '대한제분', '교촌에프앤비', '삼양식품', '푸드웰', 'MH에탄올', '풀무원', '동원F&B', '무학', '남양유업', '풍국주정', '농심', '하이트진로홀딩스', '진로발효', 'SPC삼립', '농심홀딩스', '창해에탄올', '매일홀딩스', '하이트진로', '보해양조', '우양', '매일유업', '흥국에프엔비'], '식품': ['한성기업', '오뚜기', '미래생명자원', '정다운', '마니커에프앤지', '신라교역', '교촌에프앤비', 'CJ제일제당', '오리온', '사조오양', '삼양식품', '푸드웰', '대상', '카나리아바이오', 'MH에탄올', '보라티알', '롯데웰푸드', '조흥', '팜스코', '에스앤디', '고려산업', '인산가', '풀무원', '이지바이오', '동원F&B', '하림', '하림지주', '오에스피', '체리부로', '동원수산', '동원산업', '케이씨피드', '우성', '사조산업', '이지홀딩스', '동우팜투테이블', '동서', '농심', '신라에스지', '선진', '해태제과식품', '마니커', '엠에스씨', '삼양사', '팜스토리', '진로발효', '빙그레', 'SPC삼립', '대한제당', '농심홀딩스', '샘표', '크라운해태홀딩스', '현대코퍼레이션홀딩스', 'DSEN', '샘표식품', '우양', '신송홀딩스', '한국맥널티', '매일유업', '크라운제과', '에이치피오', '대주산업', 'CJ씨푸드', '사조동아원', '한일사료', '보락', '커머스마이너', '흥국에프엔비', '사조씨푸드', '사조대림'], '가정용품': ['삼정펄프', 'TS트릴리온', '전진바이오팜', '모나리자', '태양'], '개인용품': ['CJ프레시웨이', '보라티알', 'TS트릴리온', '큐로홀딩스', '메지온', '비비씨', '보락', '교촌에프앤비', '현대코퍼레이션홀딩스', 'DSEN', '동서', '신라에스지']}

# %%
mid_class = {
    '식품과 기본 식료품 소매' : ['약품 소매', '식품 도매', '식품 소매'],
    '음식료품' : ['음료', '식품'],
    '가정용품과 개인용품' : ['가정용품', '개인용품']
}

# %%
# 소분류 -> 중분류
new_classification_companies = {}

for new_category, old_categories in mid_class.items():
    new_classification_companies[new_category] = []
    
    for old_category in old_categories:
        if old_category in small_dict:
            new_classification_companies[new_category].extend(small_dict[old_category])
            
    # 중복된 기업명 제거
    new_classification_companies[new_category] = list(set(new_classification_companies[new_category]))

# 새로운 분류로 DataFrame을 생성하고 CSV로 저장한다
df_new_classified = pd.DataFrame.from_dict(new_classification_companies, orient='index').transpose()
df_new_classified.to_csv('필수소비재_중분류_기업들.csv', index=False, encoding='cp949')

# %% [markdown]
# # 중분류 -> 대분류

# %%
big_class = {
    '필수소비재' : ['식품과 기본 식료품 소매', '음식료품', '가정용품과 개인용품']
}

# %%
# CSV 파일을 읽는다
df = pd.read_csv("필수소비재_중분류_기업들.csv", encoding='cp949')

# DataFrame을 딕셔너리로 변환한다
mid_dict = {}
for column in df.columns:
    # NaN 값은 무시한다
    mid_dict[column] = df[column].dropna().tolist()

print(mid_dict)
# Out:
# {'식품과 기본 식료품 소매': ['사조씨푸드', '한성기업', '큐로홀딩스', '오뚜기', '미래생명자원', '정다운', '마니커에프앤지', '교촌에프앤비', 'CJ제일제당', '오리온', '한국가구', '사조오양', '삼양식품', '푸드웰', '대상', '카나리아바이오', 'MH에탄올', 'CJ프레시웨이', '보라티알', '롯데웰푸드', '조흥', '팜스코', '에스앤디', '풀무원', '인산가', '하림지주', '이지바이오', '하림', '동원F&B', '남양유업', '오에스피', '동원수산', '이지홀딩스', '케이씨피드', '사조산업', '동서', '신라에스지', '농심', '선진', '해태제과식품', '엠에스씨', '삼양사', '팜스토리', '진로발효', '빙그레', 'SPC삼립', '대한제당', '농심홀딩스', '모나리자', '샘표', '크라운해태홀딩스', '현대코퍼레이션홀딩스', '케이엠제약', 'DSEN', '샘표식품', '보해양조', '우양', '신송홀딩스', '한국맥널티', '크라운제과', '에이치피오', '대주산업', 'CJ씨푸드', '한일사료', '보락', '커머스마이너', '흥국에프엔비', '스피어파워', '사조대림'], '음식료품': ['제주맥주', '오뚜기', '정다운', '마니커에프앤지', '사조오양', '삼양식품', '푸드웰', '고려산업', '조흥', '동원F&B', '무학', '하림', '풍국주정', '동원수산', '동원산업', '동서', '마니커', '엠에스씨', '삼양사', '진로발효', '대한제당', '크라운해태홀딩스', '하이트진로', '신송홀딩스', '매일유업', '크라운제과', '에이치피오', '사조씨푸드', '한성기업', '오리온', '카나리아바이오', 'MH에탄올', '하림지주', '오에스피', '인산가', '우성', '사조산업', '신라에스지', '하이트진로홀딩스', '팜스토리', 'SPC삼립', '농심홀딩스', '샘표', 'DSEN', '우양', '한국맥널티', '대주산업', '사조동아원', '대한제분', '미래생명자원', '팜스코', '풀무원', '이지바이오', '이지홀딩스', '동우팜투테이블', '농심', '선진', '빙그레', '창해에탄올', '샘표식품', 'CJ씨푸드', '신라교역', '교촌에프앤비', 'CJ제일제당', '대상', '보라티알', '롯데웰푸드', '에스앤디', '체리부로', '남양유업', '케이씨피드', '해태제과식품', '매일홀딩스', '현대코퍼레이션홀딩스', '보해양조', '한일사료', '보락', '커머스마이너', '흥국에프엔비', '사조대림'], '가정용품과 개인용품': ['CJ프레시웨이', '전진바이오팜', '삼정펄프', 'TS트릴리온', '보라티알', '큐로홀딩스', '메지온', '모나리자', '태양', '비비씨', '보락', '교촌에프앤비', '현대코퍼레이션홀딩스', 'DSEN', '동서', '신라에스지']}

# %%
# 중분류 -> 대분류
new_classification_companies = {}

for new_category, old_categories in big_class.items():
    new_classification_companies[new_category] = []
    
    for old_category in old_categories:
        if old_category in mid_dict:
            new_classification_companies[new_category].extend(mid_dict[old_category])
            
    # 중복된 기업명 제거
    new_classification_companies[new_category] = list(set(new_classification_companies[new_category]))

# 새로운 분류로 DataFrame을 생성하고 CSV로 저장한다
df_new_classified = pd.DataFrame.from_dict(new_classification_companies, orient='index').transpose()
df_new_classified.to_csv('필수소비재_대분류_기업들.csv', index=False, encoding='cp949')

# %%
# CSV 파일을 읽는다
df = pd.read_csv("필수소비재_대분류_기업들.csv", encoding='cp949')

# DataFrame을 딕셔너리로 변환한다
big_dict = {}
for column in df.columns:
    # NaN 값은 무시한다
    big_dict[column] = df[column].dropna().tolist()

print(big_dict)
# Out:
# {'필수소비재': ['제주맥주', '전진바이오팜', '오뚜기', '정다운', '마니커에프앤지', '사조오양', '한국가구', '삼양식품', '푸드웰', '고려산업', '조흥', '하림', '동원F&B', '무학', '풍국주정', '동원수산', '동원산업', '동서', '마니커', '엠에스씨', '삼양사', '진로발효', '대한제당', '크라운해태홀딩스', '하이트진로', '신송홀딩스', 'TS트릴리온', '에이치피오', '크라운제과', '매일유업', '사조씨푸드', '한성기업', '큐로홀딩스', '오리온', '카나리아바이오', 'MH에탄올', 'CJ프레시웨이', '하림지주', '오에스피', '인산가', '우성', '사조산업', '신라에스지', '하이트진로홀딩스', '팜스토리', 'SPC삼립', '메지온', '농심홀딩스', '샘표', 'DSEN', '우양', '한국맥널티', '대주산업', '사조동아원', '대한제분', '미래생명자원', '팜스코', '풀무원', '이지바이오', '이지홀딩스', '동우팜투테이블', '농심', '선진', '빙그레', '모나리자', '창해에탄올', '케이엠제약', '샘표식품', 'CJ씨푸드', '스피어파워', '신라교역', '교촌에프앤비', 'CJ제일제당', '대상', '보라티알', '롯데웰푸드', '에스앤디', '삼정펄프', '체리부로', '남양유업', '케이씨피드', '해태제과식품', '비비씨', '매일홀딩스', '현대코퍼레이션홀딩스', '보해양조', '한일사료', '보락', '커머스마이너', '태양', '흥국에프엔비', '사조대림']}
