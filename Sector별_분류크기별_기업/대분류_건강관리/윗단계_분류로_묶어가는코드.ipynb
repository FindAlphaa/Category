# %% [markdown]
# # description과 리프노드분류로 분류한 정보가 있는 파일

# %%
import pandas as pd
data = pd.read_csv("건강관리_개요_리프.csv", encoding='cp949')

new_classification_dict = {}

for _, row in data.iterrows():
    # 'sub_classfication' 값이 문자열인지 확인
    if isinstance(row['sub_classfication'], str):
        # 각 sub_classfication 값을 쉼표로 분리
        for category in row['sub_classfication'].split(', '):
            companies = new_classification_dict.get(category, [])
            if row['Company'] not in companies:
                companies.append(row['Company'])
            new_classification_dict[category] = companies

new_classification_dict
# Out:
# {'건강관리 판매업체': ['녹십자홀딩스',
#   '명문제약',
#   '삼성제약',
#   '제일파마홀딩스',
#   '한미사이언스',
#   '강스템바이오텍',
#   '농우바이오',
#   '대한과학',
#   '동구바이오제약',
#   '미코바이오메드',
#   '셀바스헬스케어',
#   '아이센스',
#   '앱클론',
#   '에이디엠코리아',
#   '제일바이오',
#   '조아제약',
#   '프롬바이오',
#   '피제이전자',
#   '녹십자',
#   '대원제약',
#   '에이프로젠바이오로직스',
#   '한미약품',
#   '한올바이오파마',
#   '환인제약',
#   'CMG제약',
#   '나노엔텍',
#   '나이벡',
#   '뉴트리',
#   '대봉엘에스',
#   '루트로닉',
#   '메타바이오메드',
#   '비엘',
#   '솔고바이오',
#   '안국약품',
#   '압타바이오',
#   '이글벳',
#   '제놀루션',
#   '제이브이엠',
#   '테고사이언스',
#   '팜스빌',
#   '국제약품',
#   '바이오노트',
#   '삼일제약',
#   '일성신약',
#   'DXVX',
#   '경남제약',
#   '국전약품',
#   '더블유에스아이',
#   '동국제약',
#   '레고켐바이오',
#   '비보존 제약',
#   '비씨월드제약',
#   '비피도',
#   '세운메디칼',
#   '알피바이오',
#   '얼라인드',
#   '우진비앤지',
#   '인바디',
#   '케어젠',
#   '코렌텍',
#   '코스맥스엔비티',
#   '코오롱생명과학',
#   '파마리서치',
#   '하이로닉',
#   '대웅제약',
#   '동화약품',
#   '셀트리온',
#   '이연제약',
#   'HK이노엔',
#   'JW신약',
#   '경동제약',
#   '대성미생물',
#   '디알젬',
#   '디알텍',
#   '디엔에이링크',
#   '레이언스',
#   '메디톡스',
#   '셀트리온헬스케어',
#   '아시아종묘',
#   '에스바이오메딕스',
#   '엘앤씨바이오',
#   '이수앱지스',
#   '제노레이',
#   '제이시스메디칼',
#   '지씨셀',
#   '케이바이오',
#   '퓨쳐켐',
#   '프리시젼바이오',
#   '하이텍팜',
#   '휴럼',
#   'JW중외제약',
#   'SK바이오사이언스',
#   '부광약품',
#   '서흥',
#   '신풍제약',
#   '한독',
#   '대화제약',
#   '디오',
#   '바이오다인',
#   '바텍',
#   '블레이드 Ent',
#   '서울제약',
#   '에이프로젠 H&G',
#   '엠아이텍',
#   '인피니트헬스케어',
#   '일신바이오',
#   '중앙백신',
#   '진바이오텍',
#   '진시스템',
#   '진양제약',
#   '큐리언트',
#   '클래시스',
#   '테라젠이텍스',
#   '휴메딕스',
#   '휴온스',
#   '광동제약',
#   '덴티움',
#   '동성제약',
#   '에스디바이오센서',
#   '영진약품',
#   '팜젠사이언스',
#   '한컴라이프케어',
#   'HLB',
#   '대한약품',
#   '바이오플러스',
#   '뷰웍스',
#   '비올',
#   '삼천당제약',
#   '수젠텍',
#   '시너지이노베이션',
#   '신일제약',
#   '씨티씨바이오',
#   '에이치엘사이언스',
#   '위더스제약',
#   '제넨바이오',
#   '지노믹트리',
#   '지더블유바이텍',
#   '코미팜',
#   '티앤엘',
#   '파나진',
#   '플라즈맵',
#   '피엔케이피부임상연구센타',
#   '한국파마',
#   '화일약품',
#   '휴비츠',
#   '삼진제약',
#   '에이프로젠',
#   '오리엔트바이오',
#   '일동제약',
#   '현대약품',
#   '네오펙트',
#   '녹십자엠에스',
#   '레이',
#   '메디포스트',
#   '멕아이씨에스',
#   '비엘팜텍',
#   '쎌바이오텍',
#   '아미노로직스',
#   '엘앤케이바이오',
#   '유틸렉스',
#   '지엘팜텍',
#   '진매트릭스',
#   '콜마비앤에이치',
#   '대웅',
#   '동아쏘시오홀딩스',
#   '신흥',
#   '유유제약',
#   '일양약품',
#   '진원생명과학',
#   '녹십자웰빙',
#   '덴티스',
#   '라이프시맨틱스',
#   '메디아나',
#   '바디텍메드',
#   '삼아제약',
#   '셀트리온제약',
#   '신신제약',
#   '알리코제약',
#   '엔젠바이오',
#   '오스코텍',
#   '이루다',
#   '인터로조',
#   '코아스템켐온',
#   '퀀타매트릭스',
#   '팬젠',
#   '휴젤'],
#  '건강관리 서비스': ['녹십자홀딩스',
#   '명문제약',
#   '제일파마홀딩스',
#   'CJ 바이오사이언스',
#   '노을',
#   '대한과학',
#   '루닛',
#   '에이디엠코리아',
#   '녹십자',
#   '동아에스티',
#   '이지케어텍',
#   '제놀루션',
#   '젠큐릭스',
#   'DXVX',
#   '신테카바이오',
#   '제넥신',
#   '케어랩스',
#   '디엔에이링크',
#   '랩지노믹스',
#   '씨엔알리서치',
#   '지씨셀',
#   '차바이오텍',
#   '프레스티지바이오로직스',
#   '휴럼',
#   '바텍',
#   '블레이드 Ent',
#   '인피니트헬스케어',
#   '지니너스',
#   '진시스템',
#   'EDGC',
#   '에이치엘사이언스',
#   '지노믹트리',
#   '코미팜',
#   '피엔케이피부임상연구센타',
#   '네오펙트',
#   '마크로젠',
#   '바이오솔루션',
#   '뷰노',
#   '솔본',
#   '유바이오로직스',
#   '신흥',
#   '드림씨아이에스',
#   '엔젠바이오',
#   '우정바이오',
#   '유비케어',
#   '클리노믹스',
#   '팬젠',
#   '피씨엘'],
#  '헬스케어 관리': ['녹십자홀딩스',
#   '제일파마홀딩스',
#   '한미사이언스',
#   'CJ 바이오사이언스',
#   '모비스',
#   '씨유메디칼',
#   '에이프로젠바이오로직스',
#   '비트컴퓨터',
#   '솔고바이오',
#   '이지케어텍',
#   '제이브이엠',
#   '팜스빌',
#   'DXVX',
#   '고려제약',
#   '케어랩스',
#   '동화약품',
#   '비스토스',
#   '씨엔알리서치',
#   '차바이오텍',
#   '씨젠',
#   '인피니트헬스케어',
#   '휴메딕스',
#   '한컴라이프케어',
#   'EDGC',
#   'HLB',
#   '신일제약',
#   '아미코젠',
#   '에이치엘사이언스',
#   '에이프로젠',
#   '솔본',
#   '콜마비앤에이치',
#   '유유제약',
#   '셀트리온제약',
#   '우정바이오',
#   '유비케어',
#   '클리노믹스'],
#  '제약': ['녹십자홀딩스',
#   '명문제약',
#   '보령',
#   '삼성제약',
#   '제일약품',
#   '제일파마홀딩스',
#   '종근당홀딩스',
#   '한미사이언스',
#   '강스템바이오텍',
#   '동구바이오제약',
#   '바이넥스',
#   '바이오에프디엔씨',
#   '바이오인프라',
#   '앱클론',
#   '에이디엠코리아',
#   '에이프릴바이오',
#   '제일바이오',
#   '조아제약',
#   '티앤알바이오팹',
#   '녹십자',
#   '대원제약',
#   '동아에스티',
#   '에이프로젠바이오로직스',
#   '일동홀딩스',
#   '한미약품',
#   '한올바이오파마',
#   '환인제약',
#   'CMG제약',
#   '고바이오랩',
#   '나이벡',
#   '대봉엘에스',
#   '보로노이',
#   '비엘',
#   '안국약품',
#   '압타머사이언스',
#   '에스티팜',
#   '엔지켐생명과학',
#   '옵투스제약',
#   '제놀루션',
#   '테고사이언스',
#   '파멥신',
#   '한국비엔씨',
#   '휴온스글로벌',
#   '국제약품',
#   '삼성바이오로직스',
#   '삼일제약',
#   '일성신약',
#   '종근당바이오',
#   'DXVX',
#   '경남제약',
#   '고려제약',
#   '국전약품',
#   '더블유에스아이',
#   '동국제약',
#   '레고켐바이오',
#   '비보존 제약',
#   '비씨월드제약',
#   '비피도',
#   '샤페론',
#   '세운메디칼',
#   '신라젠',
#   '알피바이오',
#   '애니젠',
#   '에이비엘바이오',
#   '엔케이맥스',
#   '우진비앤지',
#   '제넥신',
#   '케어젠',
#   '코오롱생명과학',
#   '파마리서치',
#   '한국유니온제약',
#   '대웅제약',
#   '동화약품',
#   '셀트리온',
#   '이연제약',
#   'HK이노엔',
#   'JW신약',
#   '경동제약',
#   '대성미생물',
#   '메드팩토',
#   '메디톡스',
#   '바이오톡스텍',
#   '셀트리온헬스케어',
#   '씨엔알리서치',
#   '아이큐어',
#   '에스바이오메딕스',
#   '에스씨엠생명과학',
#   '엘앤씨바이오',
#   '이수앱지스',
#   '이오플로우',
#   '제테마',
#   '차바이오텍',
#   '퓨쳐켐',
#   '프레스티지바이오로직스',
#   '하이텍팜',
#   'JW중외제약',
#   'JW홀딩스',
#   'SK바이오사이언스',
#   '부광약품',
#   '서흥',
#   '신풍제약',
#   '유한양행',
#   '한독',
#   'HLB제약',
#   'HLB테라퓨틱스',
#   '대화제약',
#   '블레이드 Ent',
#   '서울제약',
#   '에이프로젠 H&G',
#   '일신바이오',
#   '중앙백신',
#   '진양제약',
#   '큐리언트',
#   '테라젠이텍스',
#   '휴메딕스',
#   '휴온스',
#   'JW생명과학',
#   '광동제약',
#   '동성제약',
#   '영진약품',
#   '팜젠사이언스',
#   '하나제약',
#   'HLB',
#   '대한약품',
#   '바이오플러스',
#   '바이젠셀',
#   '삼천당제약',
#   '셀레믹스',
#   '시너지이노베이션',
#   '신일제약',
#   '씨티씨바이오',
#   '아미코젠',
#   '알테오젠',
#   '애드바이오텍',
#   '위더스제약',
#   '인벤티지랩',
#   '제넨바이오',
#   '코미팜',
#   '피엔케이피부임상연구센타',
#   '한국파마',
#   '화일약품',
#   '경보제약',
#   '더메디팜',
#   '삼진제약',
#   '에이프로젠',
#   '오리엔트바이오',
#   '일동제약',
#   '현대약품',
#   'HLB바이오스텝',
#   '그린생명과학',
#   '녹십자엠에스',
#   '메디포스트',
#   '바이오솔루션',
#   '쎌바이오텍',
#   '아미노로직스',
#   '유바이오로직스',
#   '유틸렉스',
#   '제노포커스',
#   '지놈앤컴퍼니',
#   '지엘팜텍',
#   '콜마비앤에이치',
#   '펩트론',
#   '대웅',
#   '동아쏘시오홀딩스',
#   '유유제약',
#   '일양약품',
#   '종근당',
#   '진원생명과학',
#   '네이처셀',
#   '녹십자웰빙',
#   '드림씨아이에스',
#   '디티앤씨알오',
#   '삼아제약',
#   '셀트리온제약',
#   '신신제약',
#   '아이진',
#   '알리코제약',
#   '오스코텍',
#   '우정바이오',
#   '인트론바이오',
#   '카이노스메드',
#   '코아스템켐온',
#   '티움바이오',
#   '팬젠',
#   '휴젤'],
#  '건강관리 시설': ['보령',
#   '모비스',
#   '씨유메디칼',
#   '아이센스',
#   '대원제약',
#   '한올바이오파마',
#   '환인제약',
#   '비트컴퓨터',
#   '솔고바이오',
#   '안국약품',
#   '이지케어텍',
#   '제이브이엠',
#   '국제약품',
#   '알피바이오',
#   '한국유니온제약',
#   '메디톡스',
#   '제노레이',
#   '제이시스메디칼',
#   '케이바이오',
#   '퓨쳐켐',
#   '피플바이오',
#   'JW중외제약',
#   'SK바이오사이언스',
#   '블레이드 Ent',
#   '씨젠',
#   '클래시스',
#   '광동제약',
#   '대한약품',
#   '셀레믹스',
#   '시너지이노베이션',
#   '씨티씨바이오',
#   '차백신연구소',
#   '한국파마',
#   '화일약품',
#   '더메디팜',
#   '녹십자엠에스',
#   '펩트론',
#   '동아쏘시오홀딩스',
#   '유유제약',
#   '셀트리온제약',
#   '알리코제약',
#   '우정바이오',
#   '퀀타매트릭스'],
#  '생물공학': ['삼성제약',
#   '종근당홀딩스',
#   '강스템바이오텍',
#   '동구바이오제약',
#   '루닛',
#   '미코바이오메드',
#   '바이넥스',
#   '아스타',
#   '아이센스',
#   '에이디엠코리아',
#   '제일바이오',
#   '큐라티스',
#   '티앤알바이오팹',
#   '프롬바이오',
#   '대원제약',
#   '동아에스티',
#   '일동홀딩스',
#   '한올바이오파마',
#   'CMG제약',
#   '고바이오랩',
#   '나이벡',
#   '보로노이',
#   '비엘',
#   '압타머사이언스',
#   '이노테라피',
#   '테고사이언스',
#   '파멥신',
#   '팜스빌',
#   '휴온스글로벌',
#   '바이오노트',
#   '삼성바이오로직스',
#   'DXVX',
#   '박셀바이오',
#   '비피도',
#   '신테카바이오',
#   '애니젠',
#   '얼라인드',
#   '우진비앤지',
#   '케어젠',
#   '코렌텍',
#   '코오롱생명과학',
#   '파마리서치',
#   '대웅제약',
#   '셀트리온',
#   '디엔에이링크',
#   '메디톡스',
#   '바이오톡스텍',
#   '셀트리온헬스케어',
#   '씨엔알리서치',
#   '엘앤씨바이오',
#   '이수앱지스',
#   '제테마',
#   '지씨셀',
#   '차바이오텍',
#   '케이바이오',
#   '프레스티지바이오로직스',
#   'SK바이오사이언스',
#   '바이오니아',
#   '바이오다인',
#   '싸이토젠',
#   '에이비온',
#   '에이프로젠 H&G',
#   '일신바이오',
#   '지니너스',
#   '진바이오텍',
#   '테라젠이텍스',
#   '헬릭스미스',
#   'JW생명과학',
#   '에스디바이오센서',
#   '영진약품',
#   '바이젠셀',
#   '서린바이오',
#   '셀레믹스',
#   '셀리드',
#   '시너지이노베이션',
#   '아미코젠',
#   '알테오젠',
#   '에이치엘사이언스',
#   '제넨바이오',
#   '지노믹트리',
#   '차백신연구소',
#   '파나진',
#   '에이프로젠',
#   'HLB바이오스텝',
#   '바이오솔루션',
#   '쎌바이오텍',
#   '유바이오로직스',
#   '큐라클',
#   '동아쏘시오홀딩스',
#   '진원생명과학',
#   '드림씨아이에스',
#   '마이크로디지탈',
#   '셀트리온제약',
#   '아이진',
#   '원바이오젠',
#   '인트론바이오',
#   '퀀타매트릭스',
#   '클리노믹스',
#   '티움바이오',
#   '팬젠',
#   '휴젤'],
#  '건강관리 기술': ['제일약품',
#   'CJ 바이오사이언스',
#   '강스템바이오텍',
#   '노을',
#   '대한과학',
#   '동구바이오제약',
#   '루닛',
#   '미코바이오메드',
#   '바이오에프디엔씨',
#   '아스타',
#   '아이센스',
#   '앱클론',
#   '에이디엠코리아',
#   '에이프릴바이오',
#   '제일바이오',
#   '큐라티스',
#   '티앤알바이오팹',
#   '프로테옴텍',
#   '일동홀딩스',
#   '한미약품',
#   'CMG제약',
#   '나노엔텍',
#   '나이벡',
#   '대봉엘에스',
#   '보로노이',
#   '비엘',
#   '셀바스AI',
#   '압타바이오',
#   '이노테라피',
#   '젠큐릭스',
#   '파멥신',
#   '팜스빌',
#   '바이오노트',
#   '삼일제약',
#   '종근당바이오',
#   'DXVX',
#   '국전약품',
#   '레고켐바이오',
#   '비보존 제약',
#   '비씨월드제약',
#   '샤페론',
#   '신라젠',
#   '신테카바이오',
#   '애니젠',
#   '얼라인드',
#   '에이비엘바이오',
#   '우진비앤지',
#   '인바디',
#   '제넥신',
#   '케어젠',
#   '파마리서치',
#   '셀트리온',
#   '메드팩토',
#   '바이오톡스텍',
#   '비스토스',
#   '씨엔알리서치',
#   '아이큐어',
#   '에스씨엠생명과학',
#   '오스테오닉',
#   '이오플로우',
#   '제테마',
#   '지씨셀',
#   '케이바이오',
#   '프레스티지바이오로직스',
#   '프리시젼바이오',
#   '바이오다인',
#   '싸이토젠',
#   '지니너스',
#   '진시스템',
#   '헬릭스미스',
#   '휴메딕스',
#   'JW생명과학',
#   '하나제약',
#   'EDGC',
#   '바이오플러스',
#   '바이젠셀',
#   '뷰웍스',
#   '세종메디칼',
#   '셀레믹스',
#   '셀리드',
#   '수젠텍',
#   '씨티씨바이오',
#   '아미코젠',
#   '알테오젠',
#   '애드바이오텍',
#   '에이치엘사이언스',
#   '인벤티지랩',
#   '차백신연구소',
#   '티앤엘',
#   '파나진',
#   '플라즈맵',
#   '피엔케이피부임상연구센타',
#   '휴비츠',
#   '삼진제약',
#   '네오펙트',
#   '레이',
#   '마크로젠',
#   '바이오솔루션',
#   '뷰노',
#   '솔본',
#   '유틸렉스',
#   '제노포커스',
#   '제이엘케이',
#   '진매트릭스',
#   '큐라클',
#   '펩트론',
#   '덴티스',
#   '라이프시맨틱스',
#   '아이진',
#   '엔젠바이오',
#   '올릭스',
#   '이루다',
#   '인터로조',
#   '인트론바이오',
#   '지아이이노베이션',
#   '카이노스메드',
#   '코아스템켐온',
#   '클리노믹스',
#   '팬젠',
#   '피씨엘',
#   '한스바이오메드'],
#  '생명과학 도구 및 서비스': ['제일약품',
#   'CJ 바이오사이언스',
#   '강스템바이오텍',
#   '농우바이오',
#   '대한과학',
#   '바이오에프디엔씨',
#   '바이오인프라',
#   '에이디엠코리아',
#   '에이프릴바이오',
#   '옵티팜',
#   '제일바이오',
#   '큐라티스',
#   '티앤알바이오팹',
#   '동아에스티',
#   '한올바이오파마',
#   '고바이오랩',
#   '나노엔텍',
#   '노바렉스',
#   '메타바이오메드',
#   '보로노이',
#   '비엘',
#   '셀바스AI',
#   '안국약품',
#   '압타머사이언스',
#   '압타바이오',
#   '제놀루션',
#   '젠큐릭스',
#   '파멥신',
#   '바이오노트',
#   '삼성바이오로직스',
#   'DXVX',
#   '더블유에스아이',
#   '레고켐바이오',
#   '박셀바이오',
#   '샤페론',
#   '신라젠',
#   '애니젠',
#   '얼라인드',
#   '에이비엘바이오',
#   '엔케이맥스',
#   '우진비앤지',
#   '제넥신',
#   '케어젠',
#   '코렌텍',
#   '코스맥스엔비티',
#   '코오롱생명과학',
#   'HK이노엔',
#   'JW신약',
#   '디엔에이링크',
#   '랩지노믹스',
#   '메드팩토',
#   '메디톡스',
#   '바이오톡스텍',
#   '아시아종묘',
#   '에스바이오메딕스',
#   '이수앱지스',
#   '제노레이',
#   '제테마',
#   '차바이오텍',
#   '케이바이오',
#   'JW중외제약',
#   'JW홀딩스',
#   'SK바이오사이언스',
#   '부광약품',
#   '한독',
#   'HLB제약',
#   'HLB테라퓨틱스',
#   '바이오니아',
#   '싸이토젠',
#   '에이비온',
#   '에이프로젠 H&G',
#   '일신바이오',
#   '중앙백신',
#   '지니너스',
#   '진바이오텍',
#   '큐리언트',
#   '테라젠이텍스',
#   '헬릭스미스',
#   '동성제약',
#   '에스디바이오센서',
#   'EDGC',
#   '바이오플러스',
#   '바이젠셀',
#   '비올',
#   '서린바이오',
#   '세종메디칼',
#   '셀레믹스',
#   '셀리드',
#   '알테오젠',
#   '에이치엘사이언스',
#   '인벤티지랩',
#   '제넨바이오',
#   '지노믹트리',
#   '지더블유바이텍',
#   '차백신연구소',
#   '오리엔트바이오',
#   '일동제약',
#   'HLB바이오스텝',
#   '네오펙트',
#   '엘앤케이바이오',
#   '유바이오로직스',
#   '유틸렉스',
#   '제이엘케이',
#   '지놈앤컴퍼니',
#   '지엘팜텍',
#   '진매트릭스',
#   '콜마비앤에이치',
#   '큐라클',
#   '종근당',
#   '녹십자웰빙',
#   '드림씨아이에스',
#   '디티앤씨알오',
#   '바디텍메드',
#   '아이진',
#   '알리코제약',
#   '엔젠바이오',
#   '오스코텍',
#   '올릭스',
#   '우정바이오',
#   '지아이이노베이션',
#   '카이노스메드',
#   '퀀타매트릭스',
#   '클리노믹스',
#   '티움바이오',
#   '휴젤'],
#  '건강관리 장비': ['노을',
#   '대한과학',
#   '동구바이오제약',
#   '모비스',
#   '미코바이오메드',
#   '바이오인프라',
#   '셀바스헬스케어',
#   '씨유메디칼',
#   '아이센스',
#   '티앤알바이오팹',
#   '프로테옴텍',
#   '피제이전자',
#   '대원제약',
#   '나노엔텍',
#   '루트로닉',
#   '메타바이오메드',
#   '솔고바이오',
#   '제놀루션',
#   '제이브이엠',
#   '한국비엔씨',
#   '휴마시스',
#   '더블유에스아이',
#   '세운메디칼',
#   '얼라인드',
#   '원텍',
#   '인바디',
#   '케어젠',
#   '코렌텍',
#   '파마리서치',
#   '하이로닉',
#   '대웅제약',
#   '동화약품',
#   '디알젬',
#   '디알텍',
#   '레이언스',
#   '비스토스',
#   '엘앤씨바이오',
#   '오스테오닉',
#   '이오플로우',
#   '제노레이',
#   '제이시스메디칼',
#   '제테마',
#   '케이바이오',
#   '프리시젼바이오',
#   '피플바이오',
#   '한독',
#   '디오',
#   '리메드',
#   '바이오니아',
#   '바이오다인',
#   '바텍',
#   '에이프로젠 H&G',
#   '엠아이텍',
#   '인피니트헬스케어',
#   '일신바이오',
#   '진시스템',
#   '클래시스',
#   '휴메딕스',
#   '덴티움',
#   '에스디바이오센서',
#   '한컴라이프케어',
#   'EDGC',
#   'HLB',
#   'HLB생명과학',
#   '바이오플러스',
#   '뷰웍스',
#   '비올',
#   '서린바이오',
#   '세종메디칼',
#   '수젠텍',
#   '시너지이노베이션',
#   '제넨바이오',
#   '지노믹트리',
#   '지더블유바이텍',
#   '티앤엘',
#   '플라즈맵',
#   '피엔케이피부임상연구센타',
#   '휴비츠',
#   '경보제약',
#   '더메디팜',
#   '오리엔트바이오',
#   '네오펙트',
#   '녹십자엠에스',
#   '레이',
#   '멕아이씨에스',
#   '엘앤케이바이오',
#   '진매트릭스',
#   '동아쏘시오홀딩스',
#   '신흥',
#   '유유제약',
#   '덴티스',
#   '드림씨아이에스',
#   '디티앤씨알오',
#   '라이프시맨틱스',
#   '마이크로디지탈',
#   '메디아나',
#   '바디텍메드',
#   '알리코제약',
#   '우정바이오',
#   '유비케어',
#   '이루다',
#   '인터로조',
#   '퀀타매트릭스',
#   '피씨엘'],
#  '건강관리 용품': ['아스타',
#   '앱클론',
#   '옵티팜',
#   '조아제약',
#   '나이벡',
#   '메타바이오메드',
#   '이노테라피',
#   '젠큐릭스',
#   '휴마시스',
#   '바이오노트',
#   '더블유에스아이',
#   '세운메디칼',
#   '파마리서치',
#   '이수앱지스',
#   '제테마',
#   '케이바이오',
#   '피플바이오',
#   '유한양행',
#   '바이오니아',
#   '씨젠',
#   'HLB',
#   'HLB생명과학',
#   '수젠텍',
#   '제넨바이오',
#   '티앤엘',
#   '파나진',
#   '더메디팜',
#   '녹십자엠에스',
#   '대웅',
#   '바디텍메드',
#   '알리코제약',
#   '원바이오젠',
#   '클리노믹스',
#   '피씨엘',
#   '한스바이오메드']}

# %% [markdown]
# # 리프노드_기업들로 csv 파일 저장코드

# %%
# 딕셔너리를 데이터프레임으로 변환
classification_df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in new_classification_dict.items()]))

# 데이터프레임을 CSV 파일로 저장
classification_csv_path = '건강관리_리프노드_기업들.csv'
classification_df.to_csv(classification_csv_path, encoding='cp949', index=False)

classification_csv_path
# Out:
# '건강관리_리프노드_기업들.csv'

# %% [markdown]
# # 리프노드 -> 소분류

# %%
# 소소분류 기업들
import pandas as pd

# CSV 파일을 읽는다
df = pd.read_csv("건강관리_리프노드_기업들.csv", encoding='cp949')

# DataFrame을 딕셔너리로 변환한다
result_dict = {}
for column in df.columns:
    # NaN 값은 무시한다
    result_dict[column] = df[column].dropna().tolist()

print(result_dict)
# Out:
# {'건강관리 판매업체': ['녹십자홀딩스', '명문제약', '삼성제약', '제일파마홀딩스', '한미사이언스', '강스템바이오텍', '농우바이오', '대한과학', '동구바이오제약', '미코바이오메드', '셀바스헬스케어', '아이센스', '앱클론', '에이디엠코리아', '제일바이오', '조아제약', '프롬바이오', '피제이전자', '녹십자', '대원제약', '에이프로젠바이오로직스', '한미약품', '한올바이오파마', '환인제약', 'CMG제약', '나노엔텍', '나이벡', '뉴트리', '대봉엘에스', '루트로닉', '메타바이오메드', '비엘', '솔고바이오', '안국약품', '압타바이오', '이글벳', '제놀루션', '제이브이엠', '테고사이언스', '팜스빌', '국제약품', '바이오노트', '삼일제약', '일성신약', 'DXVX', '경남제약', '국전약품', '더블유에스아이', '동국제약', '레고켐바이오', '비보존 제약', '비씨월드제약', '비피도', '세운메디칼', '알피바이오', '얼라인드', '우진비앤지', '인바디', '케어젠', '코렌텍', '코스맥스엔비티', '코오롱생명과학', '파마리서치', '하이로닉', '대웅제약', '동화약품', '셀트리온', '이연제약', 'HK이노엔', 'JW신약', '경동제약', '대성미생물', '디알젬', '디알텍', '디엔에이링크', '레이언스', '메디톡스', '셀트리온헬스케어', '아시아종묘', '에스바이오메딕스', '엘앤씨바이오', '이수앱지스', '제노레이', '제이시스메디칼', '지씨셀', '케이바이오', '퓨쳐켐', '프리시젼바이오', '하이텍팜', '휴럼', 'JW중외제약', 'SK바이오사이언스', '부광약품', '서흥', '신풍제약', '한독', '대화제약', '디오', '바이오다인', '바텍', '블레이드 Ent', '서울제약', '에이프로젠 H&G', '엠아이텍', '인피니트헬스케어', '일신바이오', '중앙백신', '진바이오텍', '진시스템', '진양제약', '큐리언트', '클래시스', '테라젠이텍스', '휴메딕스', '휴온스', '광동제약', '덴티움', '동성제약', '에스디바이오센서', '영진약품', '팜젠사이언스', '한컴라이프케어', 'HLB', '대한약품', '바이오플러스', '뷰웍스', '비올', '삼천당제약', '수젠텍', '시너지이노베이션', '신일제약', '씨티씨바이오', '에이치엘사이언스', '위더스제약', '제넨바이오', '지노믹트리', '지더블유바이텍', '코미팜', '티앤엘', '파나진', '플라즈맵', '피엔케이피부임상연구센타', '한국파마', '화일약품', '휴비츠', '삼진제약', '에이프로젠', '오리엔트바이오', '일동제약', '현대약품', '네오펙트', '녹십자엠에스', '레이', '메디포스트', '멕아이씨에스', '비엘팜텍', '쎌바이오텍', '아미노로직스', '엘앤케이바이오', '유틸렉스', '지엘팜텍', '진매트릭스', '콜마비앤에이치', '대웅', '동아쏘시오홀딩스', '신흥', '유유제약', '일양약품', '진원생명과학', '녹십자웰빙', '덴티스', '라이프시맨틱스', '메디아나', '바디텍메드', '삼아제약', '셀트리온제약', '신신제약', '알리코제약', '엔젠바이오', '오스코텍', '이루다', '인터로조', '코아스템켐온', '퀀타매트릭스', '팬젠', '휴젤'], '건강관리 서비스': ['녹십자홀딩스', '명문제약', '제일파마홀딩스', 'CJ 바이오사이언스', '노을', '대한과학', '루닛', '에이디엠코리아', '녹십자', '동아에스티', '이지케어텍', '제놀루션', '젠큐릭스', 'DXVX', '신테카바이오', '제넥신', '케어랩스', '디엔에이링크', '랩지노믹스', '씨엔알리서치', '지씨셀', '차바이오텍', '프레스티지바이오로직스', '휴럼', '바텍', '블레이드 Ent', '인피니트헬스케어', '지니너스', '진시스템', 'EDGC', '에이치엘사이언스', '지노믹트리', '코미팜', '피엔케이피부임상연구센타', '네오펙트', '마크로젠', '바이오솔루션', '뷰노', '솔본', '유바이오로직스', '신흥', '드림씨아이에스', '엔젠바이오', '우정바이오', '유비케어', '클리노믹스', '팬젠', '피씨엘'], '헬스케어 관리': ['녹십자홀딩스', '제일파마홀딩스', '한미사이언스', 'CJ 바이오사이언스', '모비스', '씨유메디칼', '에이프로젠바이오로직스', '비트컴퓨터', '솔고바이오', '이지케어텍', '제이브이엠', '팜스빌', 'DXVX', '고려제약', '케어랩스', '동화약품', '비스토스', '씨엔알리서치', '차바이오텍', '씨젠', '인피니트헬스케어', '휴메딕스', '한컴라이프케어', 'EDGC', 'HLB', '신일제약', '아미코젠', '에이치엘사이언스', '에이프로젠', '솔본', '콜마비앤에이치', '유유제약', '셀트리온제약', '우정바이오', '유비케어', '클리노믹스'], '제약': ['녹십자홀딩스', '명문제약', '보령', '삼성제약', '제일약품', '제일파마홀딩스', '종근당홀딩스', '한미사이언스', '강스템바이오텍', '동구바이오제약', '바이넥스', '바이오에프디엔씨', '바이오인프라', '앱클론', '에이디엠코리아', '에이프릴바이오', '제일바이오', '조아제약', '티앤알바이오팹', '녹십자', '대원제약', '동아에스티', '에이프로젠바이오로직스', '일동홀딩스', '한미약품', '한올바이오파마', '환인제약', 'CMG제약', '고바이오랩', '나이벡', '대봉엘에스', '보로노이', '비엘', '안국약품', '압타머사이언스', '에스티팜', '엔지켐생명과학', '옵투스제약', '제놀루션', '테고사이언스', '파멥신', '한국비엔씨', '휴온스글로벌', '국제약품', '삼성바이오로직스', '삼일제약', '일성신약', '종근당바이오', 'DXVX', '경남제약', '고려제약', '국전약품', '더블유에스아이', '동국제약', '레고켐바이오', '비보존 제약', '비씨월드제약', '비피도', '샤페론', '세운메디칼', '신라젠', '알피바이오', '애니젠', '에이비엘바이오', '엔케이맥스', '우진비앤지', '제넥신', '케어젠', '코오롱생명과학', '파마리서치', '한국유니온제약', '대웅제약', '동화약품', '셀트리온', '이연제약', 'HK이노엔', 'JW신약', '경동제약', '대성미생물', '메드팩토', '메디톡스', '바이오톡스텍', '셀트리온헬스케어', '씨엔알리서치', '아이큐어', '에스바이오메딕스', '에스씨엠생명과학', '엘앤씨바이오', '이수앱지스', '이오플로우', '제테마', '차바이오텍', '퓨쳐켐', '프레스티지바이오로직스', '하이텍팜', 'JW중외제약', 'JW홀딩스', 'SK바이오사이언스', '부광약품', '서흥', '신풍제약', '유한양행', '한독', 'HLB제약', 'HLB테라퓨틱스', '대화제약', '블레이드 Ent', '서울제약', '에이프로젠 H&G', '일신바이오', '중앙백신', '진양제약', '큐리언트', '테라젠이텍스', '휴메딕스', '휴온스', 'JW생명과학', '광동제약', '동성제약', '영진약품', '팜젠사이언스', '하나제약', 'HLB', '대한약품', '바이오플러스', '바이젠셀', '삼천당제약', '셀레믹스', '시너지이노베이션', '신일제약', '씨티씨바이오', '아미코젠', '알테오젠', '애드바이오텍', '위더스제약', '인벤티지랩', '제넨바이오', '코미팜', '피엔케이피부임상연구센타', '한국파마', '화일약품', '경보제약', '더메디팜', '삼진제약', '에이프로젠', '오리엔트바이오', '일동제약', '현대약품', 'HLB바이오스텝', '그린생명과학', '녹십자엠에스', '메디포스트', '바이오솔루션', '쎌바이오텍', '아미노로직스', '유바이오로직스', '유틸렉스', '제노포커스', '지놈앤컴퍼니', '지엘팜텍', '콜마비앤에이치', '펩트론', '대웅', '동아쏘시오홀딩스', '유유제약', '일양약품', '종근당', '진원생명과학', '네이처셀', '녹십자웰빙', '드림씨아이에스', '디티앤씨알오', '삼아제약', '셀트리온 ...

# %%
classification = {
    '건강관리 장비와 용품': ['건강관리 장비', '건강관리 용품'],
    '건강관리 업체 및 서비스': ['건강관리 판매업체', '건강관리 서비스', '건강관리 시설', '헬스케어 관리'],
    '건강관리 기술': ['건강관리 기술'],
    '생물공학': ['생물공학'],
    '제약': ['제약'],
    '생명과학 도구 및 서비스': ['생명과학 도구 및 서비스']
}

# %%
# 소소분류 -> 소분류
new_classification_companies = {}

for new_category, old_categories in classification.items():
    new_classification_companies[new_category] = []
    
    for old_category in old_categories:
        if old_category in result_dict:
            new_classification_companies[new_category].extend(result_dict[old_category])
            
    # 중복된 기업명 제거
    new_classification_companies[new_category] = list(set(new_classification_companies[new_category]))

# 새로운 분류로 DataFrame을 생성하고 CSV로 저장한다
df_new_classified = pd.DataFrame.from_dict(new_classification_companies, orient='index').transpose()
df_new_classified.to_csv('건강관리_소분류_기업들.csv', index=False, encoding='cp949')

# %% [markdown]
# # 소분류 -> 중분류

# %%
# CSV 파일을 읽는다
df = pd.read_csv("건강관리_소분류_기업들.csv", encoding='cp949')

# DataFrame을 딕셔너리로 변환한다
small_dict = {}
for column in df.columns:
    # NaN 값은 무시한다
    small_dict[column] = df[column].dropna().tolist()

print(small_dict)
# Out:
# {'건강관리 장비와 용품': ['오스테오닉', '나노엔텍', '디알텍', '바이오다인', '클리노믹스', '에이프로젠 H&G', '진시스템', '유비케어', '비스토스', '경보제약', '셀바스헬스케어', '이루다', '비올', '옵티팜', '네오펙트', '아이센스', '프리시젼바이오', 'HLB생명과학', '플라즈맵', '루트로닉', '제노레이', '동화약품', '얼라인드', '휴메딕스', '디알젬', '조아제약', '바이오인프라', '뷰웍스', '알리코제약', '클래시스', '세운메디칼', '지노믹트리', '제놀루션', '녹십자엠에스', '케이바이오', '대웅제약', '라이프시맨틱스', '대원제약', '파마리서치', '앱클론', '피엔케이피부임상연구센타', '바텍', '레이', '이노테라피', '아스타', '유한양행', '제이브이엠', '서린바이오', '진매트릭스', '엘앤케이바이오', '이오플로우', '더블유에스아이', '인터로조', '덴티스', '덴티움', '노을', '동구바이오제약', '더메디팜', '대웅', '신흥', 'HLB', '인바디', '디오', '씨젠', '피플바이오', '마이크로디지탈', '프로테옴텍', '모비스', '시너지이노베이션', '리메드', '대한과학', 'EDGC', '솔고바이오', '젠큐릭스', '유유제약', '미코바이오메드', '에스디바이오센서', '한컴라이프케어', '피제이전자', '메디아나', '제테마', '피씨엘', '티앤엘', '레이언스', '세종메디칼', '케어젠', '바이오니아', '휴비츠', '코렌텍', '메타바이오메드', '멕아이씨에스', '엘앤씨바이오', '우정바이오', '이수앱지스', '하이로닉', '드림씨아이에스', '원텍', '수젠텍', '씨유메디칼', '한국비엔씨', '엠아이텍', '제넨바이오', '한스바이오메드', '퀀타매트릭스', '티앤알바이오팹', '파나진', '원바이오젠', '지더블유바이텍', '오리엔트바이오', '디티앤씨알오', '제이시스메디칼', '바디텍메드', '바이오노트', '일신바이오', '인피니트헬스케어', '한독', '바이오플러스', '나이벡', '휴마시스', '동아쏘시오홀딩스'], '건강관리 업체 및 서비스': ['나노엔텍', '부광약품', '신신제약', '에이디엠코리아', '삼성제약', '디알텍', '셀트리온헬스케어', '바이오다인', '클리노믹스', '아미코젠', '에이프로젠 H&G', '진시스템', 'CMG제약', '메디톡스', '대한약품', '유비케어', '비스토스', '셀바스헬스케어', '셀트리온', '이루다', '제넥신', '차바이오텍', '비올', '고려제약', '이지케어텍', '네오펙트', '한미약품', '알피바이오', '아이센스', '프리시젼바이오', '플라즈맵', '대봉엘에스', '에이프로젠바이오로직스', '루트로닉', '제노레이', '광동제약', '콜마비앤에이치', '일양약품', '씨엔알리서치', '동화약품', '동아에스티', '얼라인드', '휴메딕스', '비피도', '테라젠이텍스', 'JW중외제약', '일성신약', '디알젬', '이글벳', '씨티씨바이오', '조아제약', '뷰웍스', '알리코제약', '코아스템켐온', '클래시스', '차백신연구소', '환인제약', '세운메디칼', '지노믹트리', '아미노로직스', '보령', '제놀루션', '녹십자엠에스', '대웅제약', '테고사이언스', '케이바이오', '라이프시맨틱스', '대원제약', '에이프로젠', '삼아제약', '파마리서치', '비트컴퓨터', '압타바이오', '영진약품', 'CJ 바이오사이언스', 'SK바이오사이언스', '앱클론', '국전약품', '한올바이오파마', '녹십자홀딩스', '피엔케이피부임상연구센타', '바텍', '레이', '동국제약', '강스템바이오텍', '서흥', '신풍제약', '지니너스', '하이텍팜', '유바이오로직스', '제이브이엠', '경동제약', '엘앤케이바이오', '진매트릭스', '서울제약', '팜스빌', '현대약품', '신테카바이오', '녹십자', '더블유에스아이', '인터로조', '덴티스', '아시아종묘', '덴티움', '비보존 제약', '노을', '동구바이오제약', '루닛', '더메디팜', '명문제약', '한미사이언스', '중앙백신', '코오롱생명과학', '녹십자웰빙', 'JW신약', '대웅', '신흥', '오스코텍', '경남제약', '에스바이오메딕스', '인바디', 'HLB', '디오', '휴젤', '일동제약', '마크로젠', '피플바이오', '씨젠', '지엘팜텍', '위더스제약', '코미팜', '국제약품', '동성제약', '모비스', '큐리언트', '대성미생물', '메디포스트', '팬젠', '시너지이노베이션', '한국유니온제약', '대한과학', '지씨셀', '비씨월드제약', '제일바이오', 'EDGC', '뷰노', '우진비앤지', '솔고바이오', '한국파마', '진양제약', '젠큐릭스', '쎌바이오텍', '유유제약', '미코바이오메드', '에스디바이오센서', '한컴라이프케어', '피제이전자', '메디아나', '농우바이오', '피씨엘', '비엘팜텍', '퓨쳐켐', '제일파마홀딩스', '대화제약', '레이언스', '티앤엘', '휴온스', '에이치엘사이언스', '케어젠', '휴비츠', '코렌텍', '코스맥스엔비티', '메타바이오메드', '진원생명과학', '멕아이씨에스', '엘앤씨바이오', '우정바이오', '이수앱지스', '하이로닉', '드림씨아이에스', '수젠텍', '프레스티지바이오로직스', '셀트리온제약', '씨유메디칼', '셀레믹스', '엠아이텍', '레고켐바이오', '팜젠사이언스', '제넨바이오', '디엔에이링크', '펩트론', '안국약품', '퀀타매트릭스', '엔젠바이오', '바이오솔루션', '뉴트리', '솔본', '파나진', '지더블유바이텍', '삼일제약', '삼천당제약', '케어랩스', '비엘', '오리엔트바이오', '휴럼', 'HK이노엔', 'DXVX', '제이시스메디칼', '바디텍메드', '유틸렉스', '바이오노트', '블레이드 Ent', '일신바이오', '인피니트헬스케어', '신일제약', '랩지노믹스', '한독', '프롬바이오', '바이오플러스', '나이벡', '화일약품', '진바이오텍', '동아쏘시오홀딩스', '이연제약', '삼진제약'], '건강관리 기술': ['오스테오닉', '나노엔텍', '에이디엠코리아', '아미코젠', '바이오다인', '클리노믹스', '진시스템', 'CMG제약', '올릭스', '비스토스', '셀트리온', '이루다', '제넥신', '에이비엘바이오', '네오펙트', '한미약품', '아이센스', '큐라티스', '프리시젼바이오', '플라즈맵', '대봉엘에스', '카이노스메드', '씨엔알리서치', '얼라인드', 'JW생명과학', '싸이토젠', '휴메딕스', '씨티씨바이오', '뷰웍스', '코아스템켐온', '차백신연구소', '케이바이오', '라이프시맨틱스', '셀리드', '파마리서치', '압타바이오', 'CJ 바이오사이언스', '신라젠', '앱클론', '국전약품', '피엔케이피부임상연구센타', '제일약품', '큐라클', '알테오젠', '레이', '강스템바이오텍', '지니너스', '이노테라피', '보로노이', '아스타', '진매트릭스', '팜스빌', '헬릭스미스', '이오플로우', '일동홀딩스', '지아이이노베이션', '신테카바이오', '하나제약', '인터로조', '덴티스', '에스씨엠생명과학', '비보존 제약', '노을', '바이오에프디엔씨', '동구바이오제약', '루닛', '바이오톡스텍', '샤페론', '인바디', '마크로젠', '셀바스AI', '프로테옴텍', '애드바이오텍', '제이엘케이', '팬젠', '대한과학', '지씨셀', '비씨월드제약', '제일바이오', 'EDGC', '뷰노', '우진비앤지', '젠큐릭스', '미코바이오메드', '아이큐어', '제테마', '피씨엘', '제노포커스', '티앤엘', '세종메디칼', '케어젠', '에이치엘사이언스', '휴비츠', '애니젠', '파멥신', '수젠텍', '프레스티지바이오로직스', '인벤티지랩', '셀레믹스', '레고켐바이오', '에이프릴바이오', '한스바이오메드', '펩트론', '인트론바이오', '엔젠바이오', '바이젠셀', '바이오솔루션', '티앤알바이오팹', ' ...

# %%
mid_class = {
    '건강관리와 서비스' : ['건강관리 장비와 용품', '건강관리 업체 및 서비스', '건강관리 기술'],
    '제약과 생물공학' : ['생물공학', '제약', '생명과학 도구 및 서비스']
}

# %%
# 소분류 -> 중분류
new_classification_companies = {}

for new_category, old_categories in mid_class.items():
    new_classification_companies[new_category] = []
    
    for old_category in old_categories:
        if old_category in small_dict:
            new_classification_companies[new_category].extend(small_dict[old_category])
            
    # 중복된 기업명 제거
    new_classification_companies[new_category] = list(set(new_classification_companies[new_category]))

# 새로운 분류로 DataFrame을 생성하고 CSV로 저장한다
df_new_classified = pd.DataFrame.from_dict(new_classification_companies, orient='index').transpose()
df_new_classified.to_csv('건강관리_중분류_기업들.csv', index=False, encoding='cp949')

# %% [markdown]
# # 중분류 -> 대분류

# %%
big_class = {
    '건강관리' : ['건강관리와 서비스', '제약과 생물공학']
}

# %%
# CSV 파일을 읽는다
df = pd.read_csv("건강관리_중분류_기업들.csv", encoding='cp949')

# DataFrame을 딕셔너리로 변환한다
mid_dict = {}
for column in df.columns:
    # NaN 값은 무시한다
    mid_dict[column] = df[column].dropna().tolist()

print(mid_dict)
# Out:
# {'건강관리와 서비스': ['오스테오닉', '나노엔텍', '부광약품', '신신제약', '디알텍', '에이디엠코리아', '삼성제약', '셀트리온헬스케어', '바이오다인', '클리노믹스', '아미코젠', '에이프로젠 H&G', '진시스템', 'CMG제약', '메디톡스', '대한약품', '유비케어', '비스토스', '경보제약', '올릭스', '셀바스헬스케어', '셀트리온', '이루다', '제넥신', '차바이오텍', '비올', '에이비엘바이오', '고려제약', '옵티팜', '네오펙트', '이지케어텍', '한미약품', '알피바이오', '아이센스', '큐라티스', '프리시젼바이오', 'HLB생명과학', '플라즈맵', '대봉엘에스', '루트로닉', '에이프로젠바이오로직스', '제노레이', '광동제약', '콜마비앤에이치', '카이노스메드', '일양약품', '씨엔알리서치', '동화약품', '동아에스티', '얼라인드', 'JW생명과학', '싸이토젠', '휴메딕스', '비피도', '테라젠이텍스', 'JW중외제약', '디알젬', '일성신약', '이글벳', '씨티씨바이오', '조아제약', '바이오인프라', '뷰웍스', '알리코제약', '코아스템켐온', '클래시스', '차백신연구소', '세운메디칼', '환인제약', '지노믹트리', '아미노로직스', '보령', '제놀루션', '녹십자엠에스', '대웅제약', '라이프시맨틱스', '케이바이오', '테고사이언스', '대원제약', '에이프로젠', '삼아제약', '파마리서치', '비트컴퓨터', '압타바이오', '영진약품', '셀리드', 'CJ 바이오사이언스', '신라젠', 'SK바이오사이언스', '앱클론', '국전약품', '한올바이오파마', '녹십자홀딩스', '피엔케이피부임상연구센타', '바텍', '제일약품', '큐라클', '레이', '알테오젠', '동국제약', '강스템바이오텍', '서흥', '신풍제약', '지니너스', '이노테라피', '하이텍팜', '유바이오로직스', '아스타', '유한양행', '제이브이엠', '서린바이오', '보로노이', '진매트릭스', '엘앤케이바이오', '경동제약', '서울제약', '팜스빌', '헬릭스미스', '이오플로우', '현대약품', '일동홀딩스', '지아이이노베이션', '신테카바이오', '하나제약', '더블유에스아이', '인터로조', '녹십자', '덴티스', '아시아종묘', '에스씨엠생명과학', '덴티움', '비보존 제약', '노을', '바이오에프디엔씨', '동구바이오제약', '더메디팜', '루닛', '명문제약', '바이오톡스텍', '한미사이언스', '중앙백신', '코오롱생명과학', '녹십자웰빙', 'JW신약', '대웅', '샤페론', '신흥', '오스코텍', '경남제약', 'HLB', '인바디', '에스바이오메딕스', '디오', '씨젠', '휴젤', '일동제약', '피플바이오', '마크로젠', '지엘팜텍', '셀바스AI', '마이크로디지탈', '프로테옴텍', '위더스제약', '코미팜', '국제약품', '애드바이오텍', '동성제약', '모비스', '큐리언트', '제이엘케이', '대성미생물', '메디포스트', '팬젠', '시너지이노베이션', '한국유니온제약', '리메드', '대한과학', '지씨셀', '비씨월드제약', '제일바이오', 'EDGC', '뷰노', '우진비앤지', '솔고바이오', '젠큐릭스', '한국파마', '진양제약', '유유제약', '쎌바이오텍', '미코바이오메드', '에스디바이오센서', '아이큐어', '한컴라이프케어', '피제이전자', '메디아나', '제테마', '농우바이오', '피씨엘', '비엘팜텍', '퓨쳐켐', '제노포커스', '제일파마홀딩스', '대화제약', '티앤엘', '레이언스', '휴온스', '세종메디칼', '케어젠', '바이오니아', '휴비츠', '코렌텍', '에이치엘사이언스', '메타바이오메드', '코스맥스엔비티', '멕아이씨에스', '엘앤씨바이오', '진원생명과학', '우정바이오', '애니젠', '이수앱지스', '하이로닉', '파멥신', '드림씨아이에스', '원텍', '수젠텍', '프레스티지바이오로직스', '인벤티지랩', '셀트리온제약', '씨유메디칼', '한국비엔씨', '엠아이텍', '제넨바이오', '셀레믹스', '레고켐바이오', '팜젠사이언스', '에이프릴바이오', '디엔에이링크', '한스바이오메드', '펩트론', '안국약품', '퀀타매트릭스', '인트론바이오', '엔젠바이오', '바이젠셀', '바이오솔루션', '뉴트리', '티앤알바이오팹', '솔본', '파나진', '원바이오젠', '지더블유바이텍', '종근당바이오', '삼일제약', '삼천당제약', '케어랩스', '오리엔트바이오', '비엘', '디티앤씨알오', '휴럼', 'HK이노엔', '아이진', '제이시스메디칼', 'DXVX', '바디텍메드', '유틸렉스', '바이오노트', '일신바이오', '블레이드 Ent', '인피니트헬스케어', '신일제약', '랩지노믹스', '한독', '프롬바이오', '바이오플러스', '나이벡', '화일약품', '휴마시스', '진바이오텍', '동아쏘시오홀딩스', '이연제약', '삼진제약', '메드팩토'], '제약과 생물공학': ['부광약품', '나노엔텍', '신신제약', '에이디엠코리아', '아미코젠', '셀트리온헬스케어', '삼성제약', '바이오다인', '클리노믹스', '에이프로젠 H&G', 'CMG제약', '메디톡스', '대한약품', '올릭스', '경보제약', '셀트리온', '제넥신', '차바이오텍', '비올', '에이비엘바이오', '고려제약', '옵티팜', '네오펙트', '한미약품', '알피바이오', '아이센스', '큐라티스', '대봉엘에스', '에이프로젠바이오로직스', '에스티팜', '광동제약', '콜마비앤에이치', '카이노스메드', '제노레이', '일양약품', '씨엔알리서치', '동화약품', '동아에스티', '얼라인드', 'JW생명과학', '싸이토젠', '휴메딕스', '비피도', '테라젠이텍스', 'JW중외제약', '일성신약', '씨티씨바이오', '조아제약', '바이오인프라', '알리코제약', '코아스템켐온', '차백신연구소', 'HLB테라퓨틱스', '환인제약', '세운메디칼', '지노믹트리', '아미노로직스', '보령', '고바이오랩', '제놀루션', '녹십자엠에스', '대웅제약', '케이바이오', '테고사이언스', '대원제약', '박셀바이오', '셀리드', '파마리서치', '에이프로젠', '삼아제약', '영진약품', '압타바이오', '신라젠', 'CJ 바이오사이언스', '휴온스글로벌', 'SK바이오사이언스', '앱클론', '국전약품', '한올바이오파마', '녹십자홀딩스', '피엔케이피부임상연구센타', '제일약품', '큐라클', '에이비온', '알테오젠', '동국제약', '강스템바이오텍', '엔케이맥스', '서흥', '노바렉스', '유바이오로직스', '지니너스', '이노테라피', '엔지켐생명과학', '보로노이', '아스타', '신풍제약', '하이텍팜', '서린바이오', '유한양행', '경동제약', '진매트릭스', '엘앤케이바이오', '서울제약', '압타머사이언스', '팜스빌', '헬릭스미스', '이오플로우', '종근당홀딩스', '일동홀딩스', '현대약품', '지아이이노베이션', '신테카바이오', '하나제약', '녹십자', '더블유에스아이', '에스씨엠생명과학', '아시아종묘', '비보존 제약', '바이오에프디엔씨', '동구바이오제약', '루닛', '더메디팜', '그린생명과학', '명문제약', 'HLB바이오스텝', '네이처셀', '바이오톡스텍', '한미사이언스', '중앙백신', '코오롱생명과학', '녹십자웰빙', 'JW신약', '샤페론', '대웅', '오스코텍', '경남제약', '에스바이오메딕스', 'HLB', '휴젤', '일동제약', '지엘팜텍', '셀바스AI', '마이크로디지탈', '위더스제약', '코미팜', '국제약품', '애드바이오텍', '동성제약', '큐리언트', '제이엘케이', '대성미생물', '메디포스트', '팬젠', '시너지이노베이션', '한국유니온제약', '대한과학', '지씨셀', '비씨월드제약', '제일바이오', 'EDGC', '바이넥스', '우진비앤지', '한국파마', '젠큐릭스', '진양제약', '쎌바이오텍', '유유제약', '미코바이오메드' ...

# %%
# 중분류 -> 대분류
new_classification_companies = {}

for new_category, old_categories in big_class.items():
    new_classification_companies[new_category] = []
    
    for old_category in old_categories:
        if old_category in mid_dict:
            new_classification_companies[new_category].extend(mid_dict[old_category])
            
    # 중복된 기업명 제거
    new_classification_companies[new_category] = list(set(new_classification_companies[new_category]))

# 새로운 분류로 DataFrame을 생성하고 CSV로 저장한다
df_new_classified = pd.DataFrame.from_dict(new_classification_companies, orient='index').transpose()
df_new_classified.to_csv('건강관리_대분류_기업들.csv', index=False, encoding='cp949')

# %%
# CSV 파일을 읽는다
df = pd.read_csv("건강관리_대분류_기업들.csv", encoding='cp949')

# DataFrame을 딕셔너리로 변환한다
big_dict = {}
for column in df.columns:
    # NaN 값은 무시한다
    big_dict[column] = df[column].dropna().tolist()

print(big_dict)
# Out:
# {'건강관리': ['오스테오닉', '부광약품', '나노엔텍', '신신제약', '디알텍', '에이디엠코리아', '삼성제약', '셀트리온헬스케어', '바이오다인', '클리노믹스', '아미코젠', '에이프로젠 H&G', '진시스템', 'CMG제약', '메디톡스', '대한약품', '유비케어', '비스토스', '경보제약', '올릭스', '셀바스헬스케어', '셀트리온', '이루다', '제넥신', '차바이오텍', '비올', '에이비엘바이오', '고려제약', '옵티팜', '네오펙트', '이지케어텍', '한미약품', '알피바이오', '아이센스', '큐라티스', '프리시젼바이오', 'HLB생명과학', '플라즈맵', '대봉엘에스', '루트로닉', '에이프로젠바이오로직스', '제노레이', '광동제약', '콜마비앤에이치', '카이노스메드', '에스티팜', '일양약품', '씨엔알리서치', '동화약품', '동아에스티', '얼라인드', 'JW생명과학', '싸이토젠', '휴메딕스', '비피도', '테라젠이텍스', 'JW중외제약', '디알젬', '일성신약', '이글벳', '씨티씨바이오', '조아제약', '바이오인프라', '뷰웍스', '알리코제약', '코아스템켐온', '클래시스', '차백신연구소', 'HLB테라퓨틱스', '세운메디칼', '아미노로직스', '환인제약', '지노믹트리', '보령', '제놀루션', '녹십자엠에스', '고바이오랩', '라이프시맨틱스', '케이바이오', '대웅제약', '테고사이언스', '대원제약', '에이프로젠', '삼아제약', '파마리서치', '비트컴퓨터', '압타바이오', '영진약품', '셀리드', 'CJ 바이오사이언스', '신라젠', 'SK바이오사이언스', '휴온스글로벌', '앱클론', '국전약품', '한올바이오파마', '녹십자홀딩스', '피엔케이피부임상연구센타', '바텍', '제일약품', '큐라클', '레이', '알테오젠', '에이비온', '동국제약', '강스템바이오텍', '서흥', '엔케이맥스', '노바렉스', '신풍제약', '지니너스', '이노테라피', '하이텍팜', '유바이오로직스', '아스타', '유한양행', '제이브이엠', '서린바이오', '보로노이', '진매트릭스', '엘앤케이바이오', '경동제약', '서울제약', '팜스빌', '압타머사이언스', '헬릭스미스', '이오플로우', '현대약품', '일동홀딩스', '지아이이노베이션', '종근당홀딩스', '신테카바이오', '하나제약', '더블유에스아이', '인터로조', '녹십자', '덴티스', '아시아종묘', '에스씨엠생명과학', '덴티움', '비보존 제약', '노을', '바이오에프디엔씨', '동구바이오제약', '더메디팜', '루닛', '그린생명과학', '명문제약', 'HLB바이오스텝', '네이처셀', '바이오톡스텍', '한미사이언스', '중앙백신', '코오롱생명과학', '녹십자웰빙', 'JW신약', '박셀바이오', '대웅', '샤페론', '신흥', '오스코텍', '경남제약', 'HLB', '인바디', '에스바이오메딕스', '디오', '씨젠', '휴젤', '일동제약', '피플바이오', '마크로젠', '지엘팜텍', '엔지켐생명과학', '셀바스AI', '마이크로디지탈', '프로테옴텍', '위더스제약', '코미팜', '국제약품', '애드바이오텍', '동성제약', '모비스', '큐리언트', '제이엘케이', '대성미생물', '메디포스트', '팬젠', '시너지이노베이션', '한국유니온제약', '리메드', '대한과학', '지씨셀', '비씨월드제약', '제일바이오', 'EDGC', '뷰노', '바이넥스', '우진비앤지', '솔고바이오', '젠큐릭스', '한국파마', '진양제약', '유유제약', '쎌바이오텍', '미코바이오메드', '에스디바이오센서', '아이큐어', '한컴라이프케어', '피제이전자', '티움바이오', '메디아나', '제테마', '농우바이오', '피씨엘', '비엘팜텍', '퓨쳐켐', '제노포커스', '제일파마홀딩스', '대화제약', '티앤엘', '레이언스', '휴온스', '세종메디칼', '케어젠', '바이오니아', '휴비츠', '코렌텍', '에이치엘사이언스', '메타바이오메드', '코스맥스엔비티', '멕아이씨에스', '엘앤씨바이오', '진원생명과학', '우정바이오', '애니젠', '옵투스제약', '이수앱지스', '하이로닉', '파멥신', '드림씨아이에스', '원텍', '수젠텍', 'JW홀딩스', '종근당', '프레스티지바이오로직스', '인벤티지랩', '셀트리온제약', '씨유메디칼', '한국비엔씨', '엠아이텍', '제넨바이오', '셀레믹스', '레고켐바이오', '팜젠사이언스', '에이프릴바이오', '지놈앤컴퍼니', '디엔에이링크', '한스바이오메드', '펩트론', '안국약품', '퀀타매트릭스', '인트론바이오', '엔젠바이오', '바이젠셀', '바이오솔루션', '뉴트리', '티앤알바이오팹', '솔본', '파나진', '원바이오젠', '지더블유바이텍', '종근당바이오', '삼일제약', '삼천당제약', '케어랩스', '오리엔트바이오', '비엘', '디티앤씨알오', '휴럼', 'HK이노엔', '아이진', '제이시스메디칼', 'DXVX', 'HLB제약', '바디텍메드', '유틸렉스', '바이오노트', '일신바이오', '블레이드 Ent', '인피니트헬스케어', '신일제약', '랩지노믹스', '한독', '프롬바이오', '바이오플러스', '나이벡', '화일약품', '삼성바이오로직스', '휴마시스', '진바이오텍', '동아쏘시오홀딩스', '이연제약', '삼진제약', '메드팩토']}
